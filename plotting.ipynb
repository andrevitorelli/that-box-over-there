# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
lenx = 10
x = np.linspace(.1,10,lenx)

ylist = []

N = 100
for i in range(N):
  ylist += [np.random.normal(10/x,5/x)]
y=np.array(ylist)

# %%
np.array(list(map(lambda v: [v[0], v[1], v[2]], zip(*np.percentile(y, [16, 50, 84],axis=0))))).T
# Out:
# array([[ 43.41474369,   4.22448055,   2.27598629,   0.801675  ,
#           0.95212124,   0.87919175,   0.83639328,   0.63079952,
#           0.5768295 ,   0.49430294],
#        [103.13823038,   7.90097293,   4.523201  ,   2.80794933,
#           2.0665833 ,   1.73430457,   1.44161322,   1.22921511,
#           1.08498906,   0.96533645],
#        [150.91365917,  11.64766868,   6.42926317,   4.47332713,
#           3.12212558,   2.65590272,   2.19734672,   1.90964658,
#           1.63094488,   1.47134063]])

# %%
Ym, Y, Yp = np.array(list(map(lambda v: [v[0], v[1], v[2]], zip(*np.percentile(y, [16, 50, 84],axis=0))))).T

# %%
def plotcontour(X,Y,Ym,Yp,label,color):
  plt.fill_between(X,np.array(Ym),
                   np.array(Yp),color=color,alpha=.1)
  plt.plot(X,Y,color=color,label=label)

# %%
color='red'
label='experiment'
plt.style.use('ggplot')
plotcontour(x,Y,Ym,Yp,label,color)
plt.yscale('log')
